// %% [markdown]
// ##Outsourcing Online Education: Predation and Obfuscation in Public University-OPM Contracts
// #By Laura T. Hamilton, Heather A. Daniels, Christian Michael Smith, and Charlie Eaton
// #Code by Heather Daniels
// #Table 4. Relationship between Third-Party Financing Structure and Partnership Features

// %%
copy "https://github.com/HigherEdData/Outsourcing-Online-Education/blob/0fe3d19dcc3a33dd508c0d8a85002beacece0555/data/d_OPM_database_paperJN.dta", replace
// Out:
// varlist not allowed
// r(101);

// %%
quietly {
use data/d_OPM_database_paperJN.dta, clear
set more off 
set line 255
}

// %%
*Estimates presented in AJS without robust standard errors and logit modeling*
estimates clear

qui	eststo m1VC_or_PE_dum: logit TP_recruiting VC_or_PE_dum if LMS!=1
	
qui	eststo m2VC_or_PE_dum: logit Rev_share_w_TP VC_or_PE_dum LMS
			
qui	eststo m4VC_or_PE_dum: logit TP_chgs_per_head VC_or_PE_dum LMS
	
qui	eststo m5VC_or_PE_dum: logit no_rs_ph VC_or_PE_dum LMS
	
qui	eststo m3VC_or_PE_dum: logit invisible_1 VC_or_PE_dum if LMS!=1
	
qui	eststo m6VC_or_PE_dum: logit Captivity_AR_INDEF VC_or_PE_dum 
	
qui	eststo m7VC_or_PE_dum: logit Expansion VC_or_PE_dum LMS

// %%
*Table 4*
*Relationship between Third-Party Financing Structure and Partnership Features *
esttab m1VC_or_PE_dum m2VC_or_PE_dum m4VC_or_PE_dum m5VC_or_PE_dum ///
	m3VC_or_PE_dum m7VC_or_PE_dum m6VC_or_PE_dum, ///
			se(%8.2f) b(%8.2f) star(+ 0.10 * 0.05 ** 0.01 *** 0.001) ///
			label title("Relationship between Third-Party Financing Structure and Partnership Features ") nolz

/*
Code below will export regression table in .rtf/Word file fomrmat.
Image of regression table used in paper can be viewed below.

esttab m1VC_or_PE_dum m2VC_or_PE_dum m4VC_or_PE_dum m5VC_or_PE_dum ///
	m3VC_or_PE_dum m7VC_or_PE_dum m6VC_or_PE_dum ///
		using OPM_final.rtf, ///
		se(%8.2f) b(%8.2f) star(+ 0.10 * 0.05 ** 0.01 *** 0.001) ///
		label title("Relationship between Third-Party Financing Structure and Partnership Features ") nolz replace	
*/
// Out:
// Relationship between Third-Party Financing Structure and Partnership Features
// ------------------------------------------------------------------------------------------------------------------------------------
//                               (1)             (2)             (3)             (4)             (5)             (6)             (7)
//                       Recruitment    Revenue Sh~e    Pricing pe~r    Pricing pe~e    (In)visibi~y       Expansion       Captivity
// ------------------------------------------------------------------------------------------------------------------------------------
// main
// PE/VC                        1.37***         2.57***        -1.04**         -1.62***         -.37            1.04*            .58+
//                             (.39)           (.46)           (.40)           (.37)           (.45)           (.45)           (.34)
//
// Learning Managemen~m                        -4.84***        -1.76*           4.47***                         -.72+
//                                            (1.03)           (.76)           (.64)                           (.39)
//
// Constant                    -1.29***        -1.86***         -.74*            .16            -.96*          -1.89***         -.89**
//                             (.34)           (.41)           (.29)           (.28)           (.37)           (.41)           (.30)
// ------------------------------------------------------------------------------------------------------------------------------------
// Observations                  157             224             224             224             131             226             225
// ------------------------------------------------------------------------------------------------------------------------------------
// Standard errors in parentheses
// + p<0.10, * p<0.05, ** p<0.01, *** p<0.001

// %%
%html
esttab m1VC_or_PE_dum m2VC_or_PE_dum m4VC_or_PE_dum m5VC_or_PE_dum ///
	m3VC_or_PE_dum m7VC_or_PE_dum m6VC_or_PE_dum, ///
			b(%9.2fc) se(%9.2fc) star(+ 0.10 * 0.05 ** 0.01 *** 0.001) ///
			label title("Relationship between Third-Party Financing Structure and Partnership Features") nolz ///
collabels(none) eqlabels(none) nogaps varwidth(10) html
// Out:
// This front-end or document format cannot display HTML

// %% [markdown]
// ![image.png](attachment:image.png)

// %%
*Estimates presented in CSHE with robust standard errors and linear probability modeling*
estimates clear
qui eststo m1VC_or_PE_dum: reg TP_recruiting VC_or_PE_dum if LMS!=1, vce(robust)
	
qui eststo m2VC_or_PE_dum: reg Rev_share_w_TP VC_or_PE_dum LMS, vce(robust)
			
qui eststo m4VC_or_PE_dum: reg TP_chgs_per_head VC_or_PE_dum LMS, vce(robust)
	
qui eststo m5VC_or_PE_dum: reg no_rs_ph VC_or_PE_dum LMS, vce(robust)
	
qui eststo m3VC_or_PE_dum: reg invisible_1 VC_or_PE_dum if LMS!=1, vce(robust)
	
qui eststo m6VC_or_PE_dum: reg Captivity_AR_INDEF VC_or_PE_dum, vce(robust)
	
qui eststo m7VC_or_PE_dum: reg Expansion VC_or_PE_dum LMS, vce(robust)	


esttab m1VC_or_PE_dum m2VC_or_PE_dum m4VC_or_PE_dum m5VC_or_PE_dum ///
	m3VC_or_PE_dum m7VC_or_PE_dum m6VC_or_PE_dum, ///
			se(%8.2f) b(%8.2f) star(+ 0.10 * 0.05 ** 0.01 *** 0.001) ///
			label title("Relationship between Third-Party Financing Structure and Partnership Features ") nolz	

/*
Code below will export regression table in .rtf/Word file fomrmat.
Image of regression table used in paper can be viewed below.

esttab m1VC_or_PE_dum m2VC_or_PE_dum m4VC_or_PE_dum m5VC_or_PE_dum ///
	m3VC_or_PE_dum m7VC_or_PE_dum m6VC_or_PE_dum ///
		using OPM_final_robust.rtf, ///
		se(%8.2f) b(%8.2f) star(+ 0.10 * 0.05 ** 0.01 *** 0.001) ///
		label title("Relationship between Third-Party Financing Structure and Partnership Features ") nolz replace	
*/
// Out:
// Relationship between Third-Party Financing Structure and Partnership Features
// ------------------------------------------------------------------------------------------------------------------------------------
//                               (1)             (2)             (3)             (4)             (5)             (6)             (7)
//                       Recruitment    Revenue Sh~e    Pricing pe~r    Pricing pe~e    (In)visibi~y       Expansion       Captivity
// ------------------------------------------------------------------------------------------------------------------------------------
// PE/VC                         .30***          .50***         -.17*           -.33***         -.07             .16**           .13+
//                             (.08)           (.06)           (.07)           (.07)           (.09)           (.06)           (.07)
//
// Learning Managemen~m                         -.62***         -.12**           .74***                         -.12*
//                                             (.05)           (.04)           (.05)                           (.06)
//
// Constant                      .22***          .16***          .32***          .52***          .28***          .13**           .29***
//                             (.06)           (.05)           (.06)           (.07)           (.08)           (.05)           (.06)
// ------------------------------------------------------------------------------------------------------------------------------------
// Observations                  157             224             224             224             131             226             225
// ------------------------------------------------------------------------------------------------------------------------------------
// Standard errors in parentheses
// + p<0.10, * p<0.05, ** p<0.01, *** p<0.001

// %%
%html
esttab m1VC_or_PE_dum m2VC_or_PE_dum m4VC_or_PE_dum m5VC_or_PE_dum ///
	m3VC_or_PE_dum m7VC_or_PE_dum m6VC_or_PE_dum, ///
			b(%9.2fc) se(%9.2fc) star(+ 0.10 * 0.05 ** 0.01 *** 0.001) ///
			label title("Relationship between Third-Party Financing Structure and Partnership Features ") nolz ///
collabels(none) eqlabels(none) nogaps varwidth(10) html
// Out:
// This front-end or document format cannot display HTML

// %% [markdown]
// ![image.png](attachment:image.png)
